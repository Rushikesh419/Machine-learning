# %% [markdown]
# <a href="https://colab.research.google.com/github/Rushikesh419/Machine-learning/blob/main/decisicion_trees_crossval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/penguins_size.csv')

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
df['island'].value_counts()
# Out:
# Biscoe       164
# Dream        123
# Torgersen     47
# Name: island, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %%
df[df['sex']=='.']
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 336  Gentoo  Biscoe              44.5             15.7              217.0
#
#      body_mass_g sex
# 336       4875.0   .

# %%
df[df['species']=='Gentoo'].groupby('sex').describe().transpose()
# Out:
# sex                           .       FEMALE         MALE
# culmen_length_mm  count     1.0    58.000000    61.000000
#                   mean     44.5    45.563793    49.473770
#                   std       NaN     2.051247     2.720594
#                   min      44.5    40.900000    44.400000
#                   25%      44.5    43.850000    48.100000
#                   50%      44.5    45.500000    49.500000
#                   75%      44.5    46.875000    50.500000
#                   max      44.5    50.500000    59.600000
# culmen_depth_mm   count     1.0    58.000000    61.000000
#                   mean     15.7    14.237931    15.718033
#                   std       NaN     0.540249     0.741060
#                   min      15.7    13.100000    14.100000
#                   25%      15.7    13.800000    15.200000
#                   50%      15.7    14.250000    15.700000
#                   75%      15.7    14.600000    16.100000
# ...

# %%
# by studying above data the penguine on row 336 appears to be Female
# so we change it

# %%
df.at[336,'sex']='FEMALE'

# %%
df.loc[336]
# Out:
# species              Gentoo
# island               Biscoe
# culmen_length_mm       44.5
# culmen_depth_mm        15.7
# flipper_length_mm     217.0
# body_mass_g          4875.0
# sex                  FEMALE
# Name: 336, dtype: object

# %%
sns.pairplot(df,hue='species')

# %%
sns.catplot(x='species',y='culmen_length_mm',data=df,kind='box',col='sex',palette='bright')
# Out:
# <ipython-input-27-2622e4a92b85>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='species',y='culmen_length_mm',data=df,kind='box',col='sex',palette='bright')

# %%
pd.get_dummies(df.drop('species',axis=1),drop_first=True)
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
#      island_Dream  island_Torgersen  sex_MALE
# 0               0                 1         1
# ...

# %%
X =pd.get_dummies(df.drop('species',axis=1),drop_first=True)

# %%
y=df['species']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model= DecisionTreeClassifier() # first by default

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
base_pred=model.predict(X_test)

# %%
base_pred
# Out:
# array(['Chinstrap', 'Gentoo', 'Adelie', 'Chinstrap', 'Gentoo',
#        'Chinstrap', 'Adelie', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Adelie', 'Adelie', 'Gentoo', 'Gentoo', 'Adelie', 'Gentoo',
#        'Adelie', 'Adelie', 'Adelie', 'Gentoo', 'Chinstrap', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Chinstrap', 'Gentoo', 'Adelie', 'Gentoo', 'Adelie', 'Adelie',
#        'Chinstrap', 'Adelie', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Adelie', 'Gentoo', 'Adelie', 'Adelie', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Adelie', 'Adelie',
#        'Gentoo', 'Gentoo', 'Adelie', 'Adelie', 'Chinstrap', 'Chinstrap',
#        'Gentoo', 'Adelie', 'Chinstrap', 'Gentoo', 'Adelie', 'Adelie',
#        'Chinstrap', 'Gentoo', 'Chinstrap', 'Chinstrap', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Adelie', 'Gentoo', 'Adelie',
# ...

# %%
from sklearn.metrics import ConfusionMatrixDisplay,classification_report,confusion_matrix

# %%
print(classification_report(y_test,base_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.95      0.98      0.96        41
#    Chinstrap       0.95      0.91      0.93        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.97      0.96      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %%
confusion_matrix(y_test,base_pred)
# Out:
# array([[40,  1,  0],
#        [ 2, 21,  0],
#        [ 0,  0, 37]])

# %%
ConfusionMatrixDisplay.from_estimator(model,X_test,y_test)

# %%
model.feature_importances_
# Out:
# array([0.34600162, 0.05221421, 0.53120101, 0.00239775, 0.0681854 ,
#        0.        , 0.        ])

# %%
X.columns
# Out:
# Index(['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
#        'body_mass_g', 'island_Dream', 'island_Torgersen', 'sex_MALE'],
#       dtype='object')

# %%
pd.DataFrame(index=X.columns,data=model.feature_importances_,
             columns=['feature_importance']).sort_values('feature_importance')
# Out:
#                    feature_importance
# island_Torgersen             0.000000
# sex_MALE                     0.000000
# body_mass_g                  0.002398
# culmen_depth_mm              0.052214
# island_Dream                 0.068185
# culmen_length_mm             0.346002
# flipper_length_mm            0.531201

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(10,8),dpi=100)
plot_tree(model);

# %%
# tree without column index but with column names
plt.figure(figsize=(10,8),dpi=100)
plot_tree(model,feature_names=X.columns,filled=True);

# %%
# just a function for convinience

def report_model (model):
  model_preds=model.predict(X_test)
  print(classification_report(y_test,model_preds))
  print('\n')
  plt.figure(figsize=(10,8),dpi=100)
  plot_tree(model,feature_names=X.columns,filled=True);

# %%
report_model(model)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.95      0.98      0.96        41
#    Chinstrap       0.95      0.91      0.93        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.97      0.96      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %% [markdown]
# **Exploring decision tree hyperparameters**

# %%
pruned_tree=DecisionTreeClassifier(max_depth=2)

# %%
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.88      0.92        41
#    Chinstrap       0.81      0.96      0.88        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.94       101
#    macro avg       0.93      0.94      0.93       101
# weighted avg       0.95      0.94      0.94       101

# %%
max_leaf_tree=DecisionTreeClassifier(max_leaf_nodes=3)

# %%
max_leaf_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=3)

# %%
report_model(max_leaf_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.88      0.92        41
#    Chinstrap       0.83      0.87      0.85        23
#       Gentoo       0.93      1.00      0.96        37
#
#     accuracy                           0.92       101
#    macro avg       0.91      0.92      0.91       101
# weighted avg       0.92      0.92      0.92       101

# %%
entropy_tree=DecisionTreeClassifier(criterion='entropy')

# %%
entropy_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
report_model(entropy_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.95      0.98      0.96        41
#    Chinstrap       0.95      0.91      0.93        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.97      0.96      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %% [markdown]
# **just for the salke of it do a grid search model**

# %%
param_grid={'criterion':['gini','entropy'],'max_depth':[2,3,4,5,6,7],'max_leaf_nodes':[2,3,4,5,6,7,8,9,10]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
dsc=DecisionTreeClassifier()

# %%
grid=GridSearchCV(dsc,param_grid)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 5, 6, 7],
#                          'max_leaf_nodes': [2, 3, 4, 5, 6, 7, 8, 9, 10]})

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 10}

# %%
grid.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=4, max_leaf_nodes=10)

# %%
grid_pred=grid.predict(X_test)

# %%
grid_pred
# Out:
# array(['Chinstrap', 'Gentoo', 'Adelie', 'Chinstrap', 'Gentoo',
#        'Chinstrap', 'Adelie', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Adelie', 'Adelie', 'Gentoo', 'Gentoo', 'Adelie', 'Gentoo',
#        'Adelie', 'Adelie', 'Adelie', 'Gentoo', 'Chinstrap', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Chinstrap', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie', 'Adelie',
#        'Chinstrap', 'Adelie', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Adelie', 'Gentoo', 'Adelie', 'Adelie', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Adelie', 'Adelie',
#        'Gentoo', 'Gentoo', 'Adelie', 'Adelie', 'Chinstrap', 'Chinstrap',
#        'Gentoo', 'Adelie', 'Chinstrap', 'Gentoo', 'Adelie', 'Adelie',
#        'Chinstrap', 'Gentoo', 'Chinstrap', 'Chinstrap', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Adelie', 'Gentoo', 'Adelie',
# ...

# %%
confusion_matrix(y_test,grid_pred)
# Out:
# array([[39,  2,  0],
#        [ 1, 22,  0],
#        [ 0,  0, 37]])

# %%
ConfusionMatrixDisplay.from_estimator(grid,X_test,y_test)

# %%
print(classification_report(y_test,grid_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.95      0.96        41
#    Chinstrap       0.92      0.96      0.94        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.96      0.97      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %%
# gridsearch classification treed

from sklearn.tree import export_graphviz
import graphviz

# %%
dot_data = export_graphviz(grid.best_estimator_, out_file=None, filled=True, rounded=True,
                                class_names=['0','1','2'],feature_names=X.columns)

# %%
graph = graphviz.Source(dot_data)
graph
